# %% [markdown]
# # **1)What is a random variable in probability theory?**
#
# ans- In probability theory, a random variable is a variable that represents the outcome of a random experiment. It assigns a numerical value to each possible outcome in the sample space of a probabilistic experiment.
#
# Types of Random Variables
# Discrete Random Variable:
# Takes on a countable number of possible values.
# Example: Number of heads in 3 coin tosses (values: 0, 1, 2, 3).
#
# Continuous Random Variable:
# Takes on an uncountable number of possible values, usually over an interval.
# Example: The time it takes to run a marathon (can be any non-negative real number).
#
# Formal Definition
# A random variable is a function:
#
# 𝑋
# :
# Ω
# →
# 𝑅
# X:Ω→R
# where:
#
# Ω
# Ω is the sample space (all possible outcomes),
#
# 𝑅
# R is the set of real numbers,
#
# 𝑋
# (
# 𝜔
# )
# X(ω) assigns a real number to each outcome
# 𝜔
# ∈
# Ω
# ω∈Ω.
#
# Examples
# 1. Discrete Example:
#
# Toss a fair die:
# Let
# 𝑋
# X be the result.
# Possible values of
# 𝑋
# X: {1, 2, 3, 4, 5, 6}
#
# 2. Continuous Example:
#
# Measure the height of students:
# Let
# 𝑌
# Y be the height in cm.
# Possible values of
# 𝑌
# Y: Any real number in a range like [140, 200]
#
# Why It’s Important
# Random variables allow us to:
#
# Quantify uncertainty
#
# Compute probabilities (using probability mass or density functions)
#
# Calculate statistics like expected value, variance, etc.

# %% [markdown]
# # **2) What are the types of random variables?**
#
# ans- Random variables are classified based on the type of values they can take. There are two main types:
#
# 1. Discrete Random Variable
# A discrete random variable can take on a finite or countably infinite set of distinct values.
#
# Key Characteristics:
# Values are separate and distinct (e.g., integers).
#
# Often used in counting scenarios.
#
# Examples:
# Number of heads in 5 coin tosses (0, 1, 2, 3, 4, 5)
#
# Number of students present in class
#
# Number of cars passing a traffic light in an hour
#
# Probability Function:
# Uses a Probability Mass Function (PMF)
# Example:
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# P(X=x) gives the probability that the random variable
# 𝑋
# X equals
# 𝑥
# x.
#
# 2. Continuous Random Variable
# A continuous random variable can take on an infinite number of possible values within a given interval.
#
# Key Characteristics:
# Values are from an interval of real numbers.
#
# Used in measuring scenarios.
#
# Examples:
# Temperature in a city (e.g., 23.5°C)
#
# Time taken to complete a task
#
# Height or weight of a person
#
# Probability Function:
# Uses a Probability Density Function (PDF)
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 0
# P(X=x)=0 for any exact value
# 𝑥
# x
#
# Probabilities are assigned to intervals, e.g.,
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# P(a≤X≤b)
#
# Bonus: Other Classifications (More Advanced)
# Mixed Random Variables: Have both discrete and continuous components.
#
# Multivariate Random Variables: Random vectors involving two or more random variables (e.g., joint distributions).

# %% [markdown]
# # ** 3) What is the difference between discrete and continuous distributions?**
#
# ans- The difference between discrete and continuous distributions lies in the type of values the random variable can take and how probabilities are assigned. Here's a detailed comparison:
#
# 🔢 1. Discrete Distribution
# | Feature                    | Description                                               |
# | -------------------------- | --------------------------------------------------------- |
# | **Values**                 | Takes **countable** values (finite or countably infinite) |
# | **Example Values**         | 0, 1, 2, 3, ...                                           |
# | **Probability Function**   | **Probability Mass Function (PMF)**                       |
# | **Probability at a point** | $P(X = x)$ is **non-zero** for specific values            |
# | **Graph**                  | Appears as **bars** or **spikes** (not connected)         |
# | **Examples**               | Binomial, Poisson, Geometric, Hypergeometric              |
# | **Use Case**               | Counting outcomes (e.g., number of emails in a day)       |
#
# 2. Continuous Distribution
#
# | Feature                    | Description                                              |
# | -------------------------- | -------------------------------------------------------- |
# | **Values**                 | Takes **uncountably infinite** values over intervals     |
# | **Example Values**         | Any real number in a range (e.g., 3.14, 5.72)            |
# | **Probability Function**   | **Probability Density Function (PDF)**                   |
# | **Probability at a point** | $P(X = x) = 0$; only intervals have non-zero probability |
# | **Graph**                  | Appears as a **smooth curve**                            |
# | **Examples**               | Normal (Gaussian), Exponential, Uniform, Beta            |
# | **Use Case**               | Measuring outcomes (e.g., height, weight, time)          |
#
# 🎯 Example to Illustrate the Difference
# Discrete: Tossing a coin 3 times → Number of heads (0 to 3)
#
# Continuous: Measuring the time a student takes to finish an exam → Any value like 45.3 minutes, 47.98 minutes, etc.

# %% [markdown]
# # **4)What are probability distribution functions (PDF)?**
#
# ans- ChatGPT said:
# Probability Distribution Functions (PDFs) describe how the probabilities of a random variable are distributed. There are two main types, depending on whether the random variable is discrete or continuous:
#
# 1. For Discrete Random Variables
# The function is called a Probability Mass Function (PMF).
#
# Definition:
# A PMF gives the probability that a discrete random variable is exactly equal to some value.
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# P(X=x)
# Example:
# Rolling a fair six-sided die:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1
# 6
# for
# 𝑥
# =
# 1
# ,
# 2
# ,
# .
# .
# .
# ,
# 6
# P(X=x)=
# 6
# 1
# ​
#  for x=1,2,...,6
# 2. For Continuous Random Variables
# The function is called a Probability Density Function (PDF).
#
# Definition:
# A PDF gives the relative likelihood of the variable taking on a value in a given range, not at a single point.
# The probability that
# 𝑋
# X falls within an interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b] is given by:
#
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
# Properties:
#
# 𝑓
# (
# 𝑥
# )
# ≥
# 0
# f(x)≥0 for all
# 𝑥
# x
#
# Total area under the curve = 1:
#
# ∫
# −
# ∞
# ∞
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# =
# 1
# ∫
# −∞
# ∞
# ​
#  f(x)dx=1
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 0
# P(X=x)=0 for any exact value
# 𝑥
# x
#
# Example:
# The standard normal distribution has PDF:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 2
# 𝜋
# 𝑒
# −
# 𝑥
# 2
# /
# 2
# f(x)=
# 2π
# ​
#
# 1
# ​
#  e
# −x
# 2
#  /2
#
# Summary Table
#
# | Type       | Name | Example             | Key Formula                              |
# | ---------- | ---- | ------------------- | ---------------------------------------- |
# | Discrete   | PMF  | Dice roll           | $P(X = x)$                               |
# | Continuous | PDF  | Normal distribution | $P(a \leq X \leq b) = \int_a^b f(x)\,dx$ |

# %% [markdown]
# # ** 5) How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?**
#
# ans- The Cumulative Distribution Function (CDF) and the Probability Distribution Function (PDF) (more accurately called Probability Density Function for continuous variables, or Probability Mass Function (PMF) for discrete variables) are both ways to describe the distribution of a random variable, but they serve different purposes and have different mathematical definitions:
#
# 1. Definition
# PDF (Probability Density Function) (for continuous variables):
#
# Describes the relative likelihood of the random variable taking on a specific value.
#
# Denoted as
# 𝑓
# (
# 𝑥
# )
# f(x), where
# 𝑓
# (
# 𝑥
# )
# ≥
# 0
# f(x)≥0 and
# ∫
# −
# ∞
# ∞
# 𝑓
# (
# 𝑥
# )
# 𝑑
# 𝑥
# =
# 1
# ∫
# −∞
# ∞
# ​
#  f(x)dx=1.
#
# CDF (Cumulative Distribution Function):
#
# Describes the probability that the random variable is less than or equal to a specific value.
#
# Denoted as
# 𝐹
# (
# 𝑥
# )
# F(x), and defined as:
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# =
# ∫
# −
# ∞
# 𝑥
# 𝑓
# (
# 𝑡
# )
# 𝑑
# 𝑡
# F(x)=P(X≤x)=∫
# −∞
# x
# ​
#  f(t)dt
# 2. Output
# PDF gives a density, not a probability for a single point (in continuous case).
#
# CDF gives a cumulative probability up to a point.
#
# 3. Interpretation
# PDF: "How dense is the probability around a point?"
#
# CDF: "What's the total probability accumulated up to a point?"
#
# 4. Relationship
# The CDF is the integral of the PDF:
#
# 𝐹
# (
# 𝑥
# )
# =
# ∫
# −
# ∞
# 𝑥
# 𝑓
# (
# 𝑡
# )
# 𝑑
# 𝑡
# F(x)=∫
# −∞
# x
# ​
#  f(t)dt
# The PDF is the derivative of the CDF (if differentiable):
#
# 𝑓
# (
# 𝑥
# )
# =
# 𝑑
# 𝑑
# 𝑥
# 𝐹
# (
# 𝑥
# )
# f(x)=
# dx
# d
# ​
#  F(x)
# 5. Visualization
# PDF: Curve showing peaks where values are more likely.
#
# CDF: S-curve (for continuous distributions) that starts at 0 and asymptotically approaches 1.
#
# 6. Discrete Case
# For discrete variables:
#
# PMF replaces PDF:
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# P(X=x)
#
# CDF is the sum:
# 𝐹
# (
# 𝑥
# )
# =
# ∑
# 𝑡
# ≤
# 𝑥
# 𝑃
# (
# 𝑋
# =
# 𝑡
# )
# F(x)=∑
# t≤x
# ​
#  P(X=t)
#
# Summary Table
#
# | Feature           | PDF/PMF                                | CDF                              |
# | ----------------- | -------------------------------------- | -------------------------------- |
# | Type              | Density (continuous) / Mass (discrete) | Cumulative probability           |
# | Output            | Likelihood/Density at a point          | Probability up to a point        |
# | Mathematical Form | $f(x)$, $P(X = x)$                     | $F(x) = P(X \leq x)$             |
# | Relation          | $f(x) = \frac{d}{dx} F(x)$             | $F(x) = \int_{-\infty}^x f(t)dt$ |
# | Range             | $f(x) \geq 0$, integrates to 1         | $0 \leq F(x) \leq 1$             |

# %% [markdown]
# # **6) What is a discrete uniform distribution?**
#
# ans-ChatGPT said:
# A Discrete Uniform Distribution is a type of probability distribution in which a finite number of outcomes are all equally likely. It is one of the simplest and most intuitive probability models.
#
# 📌 Definition
# A discrete random variable
# 𝑋
# X has a discrete uniform distribution if it takes on a finite number of distinct values, say
# 𝑥
# 1
# ,
# 𝑥
# 2
# ,
# …
# ,
# 𝑥
# 𝑛
# x
# 1
# ​
#  ,x
# 2
# ​
#  ,…,x
# n
# ​
#  , and:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# 𝑖
# )
# =
# 1
# 𝑛
# for all
# 𝑖
# =
# 1
# ,
# 2
# ,
# …
# ,
# 𝑛
# P(X=x
# i
# ​
#  )=
# n
# 1
# ​
#  for all i=1,2,…,n
# ✅ Key Properties
# Support (possible values): A set of
# 𝑛
# n distinct outcomes, usually
# {
# 𝑎
# ,
# 𝑎
# +
# 1
# ,
# 𝑎
# +
# 2
# ,
# …
# ,
# 𝑏
# }
# {a,a+1,a+2,…,b}
#
# 𝑛
# =
# 𝑏
# −
# 𝑎
# +
# 1
# n=b−a+1
#
# Equal probability: Every outcome has the same probability:
# 1
# 𝑛
# n
# 1
# ​
#
#
# Mean (Expected Value):
#
# 𝐸
# [
# 𝑋
# ]
# =
# 𝑎
# +
# 𝑏
# 2
# E[X]=
# 2
# a+b
# ​
#
# Variance:
#
# Var
# (
# 𝑋
# )
# =
# (
# 𝑏
# −
# 𝑎
# +
# 1
# )
# 2
# −
# 1
# 12
# Var(X)=
# 12
# (b−a+1)
# 2
#  −1
# ​
#
# 🎲 Example
# Imagine rolling a fair 6-sided die:
#
# Possible outcomes:
# {
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# }
# {1,2,3,4,5,6}
#
# Each has probability:
# 1
# 6
# 6
# 1
# ​
#
#
# This is a discrete uniform distribution over
# {
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# }
# {1,2,3,4,5,6}
#
# 📈 Probability Mass Function (PMF)
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# {
# 1
# 𝑛
# if
# 𝑥
# ∈
# {
# 𝑥
# 1
# ,
# 𝑥
# 2
# ,
# …
# ,
# 𝑥
# 𝑛
# }
# 0
# otherwise
# P(X=x)={
# n
# 1
# ​
#
# 0
# ​
#
# if x∈{x
# 1
# ​
#  ,x
# 2
# ​
#  ,…,x
# n
# ​
#  }
# otherwise
# ​
#
# 📊 Use Cases
# Simulating fair games (dice, cards, lotteries)
#
# Random sampling
#
# Modeling equally likely outcomes in algorithms

# %% [markdown]
# # **7) What are the key properties of a Bernoulli distribution?**
#
# ans- The Bernoulli distribution is one of the most fundamental probability distributions in statistics and machine learning. It models the outcome of a single binary experiment — an event that can result in either a success (1) or a failure (0).
#
# ✅ Key Properties of a Bernoulli Distribution
#
# | Property                            | Description                                                |
# | ----------------------------------- | ---------------------------------------------------------- |
# | **Type**                            | Discrete                                                   |
# | **Support**                         | $X \in \{0, 1\}$                                           |
# | **Parameter**                       | $p$, where $0 \leq p \leq 1$ (probability of success)      |
# | **PMF (Probability Mass Function)** | \[                                                         |
# | P(X = x) =                          |                                                            |
# | \begin{cases}                       |                                                            |
# | p & \text{if } x = 1 \\             |                                                            |
# | 1 - p & \text{if } x = 0            |                                                            |
# | \end{cases}                         |                                                            |
# | ]                                   |                                                            |
# | **Mean (Expected Value)**           | $\mathbb{E}[X] = p$                                        |
# | **Variance**                        | $\text{Var}(X) = p(1 - p)$                                 |
# | **Skewness**                        | $\frac{1 - 2p}{\sqrt{p(1 - p)}}$                           |
# | **Kurtosis (Excess)**               | $\frac{1 - 6p(1 - p)}{p(1 - p)}$                           |
# | **Entropy**                         | $-p\log_2(p) - (1 - p)\log_2(1 - p)$, measures uncertainty |
#
# 📊 Interpretation
# 0 = failure, with probability
# 1
# −
# 𝑝
# 1−p
#
# 1 = success, with probability
# 𝑝
# p
#
# Useful when modeling yes/no, true/false, or pass/fail type outcomes.
#
# 📍 Example
# Tossing a biased coin:
#
# 𝑋
# =
# 1
# X=1 if heads (success),
# 𝑋
# =
# 0
# X=0 if tails (failure)
#
# If the probability of heads is
# 𝑝
# =
# 0.7
# p=0.7, then:
#
# 𝑃
# (
# 𝑋
# =
# 1
# )
# =
# 0.7
# P(X=1)=0.7
#
# 𝑃
# (
# 𝑋
# =
# 0
# )
# =
# 0.3
# P(X=0)=0.3
#
# 🔄 Related Distributions
# Binomial distribution: The sum of multiple independent Bernoulli trials.
#
# Geometric distribution: Models the number of trials until the first success in repeated Bernoulli trials.
#
# Bernoulli process: A sequence of i.i.d. Bernoulli trials.

# %% [markdown]
# # **8) What is the binomial distribution, and how is it used in probability?**
#
# ans- The Binomial Distribution is a discrete probability distribution that models the number of successes in a fixed number of independent Bernoulli trials, each with the same probability of success.
#
# 🎯 Definition
# A random variable
# 𝑋
# ∼
# Bin
# (
# 𝑛
# ,
# 𝑝
# )
# X∼Bin(n,p) follows a binomial distribution if:
#
# 𝑛
# n: Number of trials
#
# 𝑝
# p: Probability of success in a single trial
#
# 𝑋
# X: Number of successes in
# 𝑛
# n trials
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# where
# 𝑘
# =
# 0
# ,
# 1
# ,
# 2
# ,
# …
# ,
# 𝑛
# k=0,1,2,…,n
#
# Key Properties:
#
# | Property                 | Formula                           |
# | ------------------------ | --------------------------------- |
# | Support                  | $X \in \{0, 1, 2, \dots, n\}$     |
# | Mean                     | $\mathbb{E}[X] = np$              |
# | Variance                 | $\text{Var}(X) = np(1 - p)$       |
# | Mode (most likely value) | $\lfloor (n + 1)p \rfloor$        |
# | Skewness                 | $\frac{1 - 2p}{\sqrt{np(1 - p)}}$ |
#
# 🧠 Intuition
# Think of repeating the same yes/no experiment
# 𝑛
# n times:
#
# You want to know how many times you get a "yes" (success)
#
# Each experiment is independent
#
# Each success has the same probability
# 𝑝
# p
#
# 🎲 Example
# Toss a fair coin 10 times. What’s the probability of getting exactly 4 heads?
#
# Let
# 𝑋
# ∼
# Bin
# (
# 𝑛
# =
# 10
# ,
# 𝑝
# =
# 0.5
# )
# X∼Bin(n=10,p=0.5)
#
# Want
# 𝑃
# (
# 𝑋
# =
# 4
# )
# P(X=4):
#
# 𝑃
# (
# 𝑋
# =
# 4
# )
# =
# (
# 10
# 4
# )
# (
# 0.5
# )
# 4
# (
# 0.5
# )
# 6
# =
# 210
# ⋅
# (
# 0.5
# )
# 10
# ≈
# 0.205
# P(X=4)=(
# 4
# 10
# ​
#  )(0.5)
# 4
#  (0.5)
# 6
#  =210⋅(0.5)
# 10
#  ≈0.205
# 📌 Common Use Cases
# Quality control: How many defective items in a batch?
#
# Medical trials: How many patients respond to a drug?
#
# Marketing: How many people click on an ad?
#
# Polling: How many voters favor a candidate?
#
# Related Distributions
#
# | Distribution          | Description                                                  |
# | --------------------- | ------------------------------------------------------------ |
# | **Bernoulli**         | Single trial with success/failure                            |
# | **Geometric**         | Trials until first success                                   |
# | **Negative Binomial** | Trials until $r$ successes                                   |
# | **Poisson**           | Approximation of Binomial when $n$ is large and $p$ is small |

# %% [markdown]
# # **9) What is the Poisson distribution and where is it applied?**
#
# ans- The Poisson distribution is a discrete probability distribution that models the number of events occurring in a fixed interval of time or space, assuming the events happen independently and at a constant average rate.
#
# 🎯 Definition
# If
# 𝑋
# ∼
# Poisson
# (
# 𝜆
# )
# X∼Poisson(λ), then the probability of observing
# 𝑘
# k events is:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# P(X=k)=
# k!
# e
# −λ
#  λ
# k
#
# ​
#
# where:
#
# 𝑘
# =
# 0
# ,
# 1
# ,
# 2
# ,
# …
# k=0,1,2,…
#
# 𝜆
# >
# 0
# λ>0: the average number of events in the interval
#
# 𝑒
# ≈
# 2.718
# e≈2.718
#
# ✅ Key Properties:
# | Property  | Value                                                                          |
# | --------- | ------------------------------------------------------------------------------ |
# | Type      | Discrete                                                                       |
# | Support   | $k \in \{0, 1, 2, \dots\}$                                                     |
# | Parameter | $\lambda$ (mean rate)                                                          |
# | Mean      | $\mathbb{E}[X] = \lambda$                                                      |
# | Variance  | $\text{Var}(X) = \lambda$                                                      |
# | Skewness  | $\frac{1}{\sqrt{\lambda}}$                                                     |
# | Mode      | $\lfloor \lambda \rfloor$ or $\lfloor \lambda \rfloor - 1$ (if not an integer) |
#
# When to Use It
# Use the Poisson distribution when you're counting the number of times an event occurs in:
#
# A fixed time period
#
# A fixed area, length, or volume
#
# Independently and at a constant average rate
#
# 🧪 Examples of Applications:
#
# | Domain         | Application Example                                    |
# | -------------- | ------------------------------------------------------ |
# | **Telecom**    | Number of calls received at a call center per hour     |
# | **Traffic**    | Number of cars passing through a toll booth per minute |
# | **Biology**    | Number of mutations in a strand of DNA per unit length |
# | **E-commerce** | Number of purchases per minute on a website            |
# | **Astronomy**  | Number of meteorites hitting Earth in a year           |
# | **Finance**    | Number of trades occurring in a second                 |
#
# 📌 Poisson as an Approximation
# The Poisson distribution can approximate the Binomial distribution when:
#
# 𝑛
# n is large
#
# 𝑝
# p is small
#
# 𝜆
# =
# 𝑛
# 𝑝
# λ=np is moderate
#
# 📈 Shape and Behavior
# For small
# 𝜆
# λ, the distribution is skewed right.
#
# As
# 𝜆
# λ increases, it becomes more symmetric (approaching normal distribution behavior).

# %% [markdown]
# # **10) What is a continuous uniform distribution?**
#
# ans- ChatGPT said:
# The Continuous Uniform Distribution is a probability distribution that describes a situation where all outcomes in a continuous range are equally likely.
#
# 🎯 Definition
# A random variable
# 𝑋
# ∼
# 𝑈
# (
# 𝑎
# ,
# 𝑏
# )
# X∼U(a,b) follows a continuous uniform distribution if it takes values in the interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b] with equal probability throughout that range.
#
# The Probability Density Function (PDF) is:
#
# 𝑓
# (
# 𝑥
# )
# =
# {
# 1
# 𝑏
# −
# 𝑎
# ,
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# 0
# ,
# otherwise
# f(x)={
# b−a
# 1
# ​
#  ,
# 0,
# ​
#
# a≤x≤b
# otherwise
# ​
#
# Key Properties:
#
# | Property                                  | Value                                  |
# | ----------------------------------------- | -------------------------------------- |
# | Type                                      | Continuous                             |
# | Support                                   | $x \in [a, b]$                         |
# | Mean                                      | $\mathbb{E}[X] = \frac{a + b}{2}$      |
# | Variance                                  | $\text{Var}(X) = \frac{(b - a)^2}{12}$ |
# | Median                                    | $\frac{a + b}{2}$                      |
# | Skewness                                  | 0 (symmetric distribution)             |
# | Entropy                                   | $\log(b - a)$                          |
# | CDF (Cumulative)                          | \[                                     |
# | F(x) =                                    |                                        |
# | \begin{cases}                             |                                        |
# | 0, & x < a \\                             |                                        |
# | \frac{x - a}{b - a}, & a \leq x \leq b \\ |                                        |
# | 1, & x > b                                |                                        |
# | \end{cases}                               |                                        |
# | ]                                         |                                        |
#
# 🧠 Intuition
# You use a continuous uniform distribution when you're dealing with a situation where any value in a range is equally likely.
#
# 🎲 Example
# Suppose a bus arrives randomly sometime between 10:00 and 10:30. Let
# 𝑋
# X be the number of minutes after 10:00 the bus arrives.
#
# Then
# 𝑋
# ∼
# 𝑈
# (
# 0
# ,
# 30
# )
# X∼U(0,30)
#
# The probability it arrives in the first 10 minutes is:
#
# 𝑃
# (
# 0
# ≤
# 𝑋
# ≤
# 10
# )
# =
# 10
# −
# 0
# 30
# −
# 0
# =
# 1
# 3
# P(0≤X≤10)=
# 30−0
# 10−0
# ​
#  =
# 3
# 1
# ​
#
# 📌 Applications:
#
# Random sampling: Generating a random float in a range
#
# Simulations: Modeling equally likely outcomes over a range
#
# Waiting times: Uniform distribution of events over a fixed time window
#
# Cryptography: Generating random keys uniformly

# %% [markdown]
# # **10) What is a continuous uniform distribution?**
#
# ans- A continuous uniform distribution is a probability distribution in which all outcomes within a given continuous interval are equally likely. It’s one of the simplest continuous distributions.
#
# 📌 Definition
# A random variable
# 𝑋
# ∼
# 𝑈
# (
# 𝑎
# ,
# 𝑏
# )
# X∼U(a,b) follows a continuous uniform distribution if:
#
# It can take any value in the interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b]
#
# Every value within that interval is equally likely
#
# 📈 Probability Density Function (PDF)
# 𝑓
# (
# 𝑥
# )
# =
# {
# 1
# 𝑏
# −
# 𝑎
# ,
# if
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# 0
# ,
# otherwise
# f(x)={
# b−a
# 1
# ​
#  ,
# 0,
# ​
#
# if a≤x≤b
# otherwise
# ​
#
# This means the height of the distribution is constant between
# 𝑎
# a and
# 𝑏
# b.
#
# 📊 Key Properties:
#
# | Property                                  | Formula                                |
# | ----------------------------------------- | -------------------------------------- |
# | **Support**                               | $x \in [a, b]$                         |
# | **Mean**                                  | $\mathbb{E}[X] = \frac{a + b}{2}$      |
# | **Variance**                              | $\text{Var}(X) = \frac{(b - a)^2}{12}$ |
# | **Median**                                | $\frac{a + b}{2}$                      |
# | **Skewness**                              | 0 (symmetrical)                        |
# | **CDF**                                   | \[                                     |
# | F(x) =                                    |                                        |
# | \begin{cases}                             |                                        |
# | 0, & x < a \\                             |                                        |
# | \frac{x - a}{b - a}, & a \leq x \leq b \\ |                                        |
# | 1, & x > b                                |                                        |
# | \end{cases}                               |                                        |
# | ]                                         |                                        |
# 🎯 Real-Life Examples
#
# Random number generation: Choosing a real number uniformly between 0 and 1.
#
# Arrival time: A bus that arrives at a random time between 2:00 and 2:30.
#
# Simulations: Assigning values where no outcome is favored.
#
# 🧠 Intuition
#
# If you randomly pick a point along a straight line segment of length 10 (from
# 𝑎
# =
# 0
# a=0 to
# 𝑏
# =
# 10
# b=10), the probability of the point falling anywhere on that segment is the same — that's a continuous uniform distribution.

# %% [markdown]
# # **11)What are the characteristics of a normal distribution?**
#
# ans- The normal distribution, also known as the Gaussian distribution, is one of the most important and widely used probability distributions in statistics and data science. It describes data that tend to cluster around a mean with symmetrical spread.
#
# Key Characteristics of a Normal Distribution:
# | Feature                                                                  | Description                                               |
# | ------------------------------------------------------------------------ | --------------------------------------------------------- |
# | **Shape**                                                                | Bell-shaped and symmetric about the mean                  |
# | **Mean (μ)**                                                             | The center of the distribution (also the median and mode) |
# | **Standard Deviation (σ)**                                               | Controls the spread; larger σ = wider curve               |
# | **Support**                                                              | All real numbers: $x \in (-\infty, \infty)$               |
# | **PDF**                                                                  | \[                                                        |
# | f(x) = \frac{1}{\sqrt{2\pi \sigma^2}} e^{-\frac{(x - \mu)^2}{2\sigma^2}} |                                                           |
# | ]                                                                        |                                                           |
# | **Symmetry**                                                             | Perfectly symmetric about the mean $\mu$                  |
# | **Skewness**                                                             | 0 (not skewed)                                            |
# | **Kurtosis**                                                             | 3 (mesokurtic, standard "peakedness")                     |
#
# 📐 Empirical Rule (68-95-99.7 Rule)
# For a normal distribution:
#
# 68% of values lie within 1 standard deviation of the mean
#
# 95% lie within 2 standard deviations
#
# 99.7% lie within 3 standard deviations
#
# 📊 Standard Normal Distribution
# Special case where
# 𝜇
# =
# 0
# μ=0,
# 𝜎
# =
# 1
# σ=1
#
# Denoted
# 𝑍
# ∼
# 𝑁
# (
# 0
# ,
# 1
# )
# Z∼N(0,1)
#
# Often used to compute Z-scores:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# 🎯 Applications
# Natural phenomena (heights, weights, blood pressure)
#
# Measurement errors
#
# Finance (modeling returns)
#
# Machine learning (assumptions in many models like linear regression)
#
# Quality control and hypothesis testing
#
# 📌 Important Notes
# The normal distribution is a theoretical model, but many real-world phenomena approximate it.
#
# Many statistical techniques assume normality for valid results.

# %% [markdown]
# # **12) What is the standard normal distribution, and why is it important?**
#
# ans- The standard normal distribution is a special case of the normal distribution where:
#
# The mean
# 𝜇
# =
# 0
# μ=0
#
# The standard deviation
# 𝜎
# =
# 1
# σ=1
#
# It's often denoted as:
#
# 𝑍
# ∼
# 𝑁
# (
# 0
# ,
# 1
# )
# Z∼N(0,1)
# This distribution plays a central role in statistics, particularly in standardization, probability calculation, and hypothesis testing.
#
# ✅ Key Features of the Standard Normal Distribution:
#
# | Property                                | Value              |
# | --------------------------------------- | ------------------ |
# | Mean ($\mu$)                            | 0                  |
# | Standard Deviation ($\sigma$)           | 1                  |
# | Symmetry                                | Symmetric around 0 |
# | Total Area Under Curve                  | 1 (100%)           |
# | PDF                                     | \[                 |
# | f(z) = \frac{1}{\sqrt{2\pi}} e^{-z^2/2} |                    |
# | ]                                       |                    |
#
#
# 🎯 Why It’s Important
# 1. Standardization (Z-scores)
# Transforms any normal variable
# 𝑋
# ∼
# 𝑁
# (
# 𝜇
# ,
# 𝜎
# 2
# )
# X∼N(μ,σ
# 2
#  ) to
# 𝑍
# ∼
# 𝑁
# (
# 0
# ,
# 1
# )
# Z∼N(0,1):
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# This allows for easy comparison between different datasets and variables with different units or scales.
#
# 2. Probability Calculations
# Most probability tables (Z-tables) are based on the standard normal.
#
# Example: To find the probability that a value is less than 1.96 standard deviations above the mean, you’d use the Z-table:
#
# 𝑃
# (
# 𝑍
# <
# 1.96
# )
# ≈
# 0.975
# P(Z<1.96)≈0.975
# 3. Hypothesis Testing & Confidence Intervals
# Z-scores are used to compute:
#
# p-values
#
# confidence intervals
#
# critical values for significance levels (e.g.,
# 𝛼
# =
# 0.05
# α=0.05)
#
# 4. Central Limit Theorem (CLT)
# The CLT states that the sampling distribution of the sample mean will approach a normal distribution as sample size increases — often standardized to
# 𝑁
# (
# 0
# ,
# 1
# )
# N(0,1) for convenience.
#
# 📊 Visual Characteristics
# Bell-shaped
#
# Symmetrical
#
# Centered at 0
#
# Most values lie between −3 and +3
#
# 🧪 Example
# If a student scores 85 on a test where the class mean is 75 and standard deviation is 5:
#
# 𝑍
# =
# 85
# −
# 75
# 5
# =
# 2.0
# Z=
# 5
# 85−75
# ​
#  =2.0
# This means the student scored 2 standard deviations above the mean, which corresponds to roughly the 97.5th percentile.

# %% [markdown]
# # **13) What is the Central Limit Theorem (CLT), and why is it critical in statistics?**
#
# ans- The Central Limit Theorem (CLT) is one of the most fundamental concepts in statistics. It explains why normal distributions are so common, even when the underlying data are not normally distributed.
#
# 🎯 Definition of the Central Limit Theorem
# The Central Limit Theorem states:
#
# Given a sufficiently large sample size, the sampling distribution of the sample mean will approximate a normal distribution, regardless of the shape of the population distribution — provided the population has a finite mean and variance.
#
# 📐 Mathematical Form
# Let:
#
# 𝑋
# 1
# ,
# 𝑋
# 2
# ,
# …
# ,
# 𝑋
# 𝑛
# X
# 1
# ​
#  ,X
# 2
# ​
#  ,…,X
# n
# ​
#   be i.i.d. random variables with mean
# 𝜇
# μ and standard deviation
# 𝜎
# σ
#
# Then the sample mean
# 𝑋
# ˉ
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# 𝑋
# 𝑖
# X
# ˉ
#  =
# n
# 1
# ​
#  ∑
# i=1
# n
# ​
#  X
# i
# ​
#
#
# As
# 𝑛
# →
# ∞
# n→∞,
#
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# →
# 𝑑
# 𝑁
# (
# 0
# ,
# 1
# )
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# d
# ​
#  N(0,1)
# This means the standardized sample mean converges in distribution to a standard normal distribution.
#
# ✅ Why It’s Critical in Statistics
#
# | Reason                                                     | Explanation                                                                                             |
# | ---------------------------------------------------------- | ------------------------------------------------------------------------------------------------------- |
# | **1. Enables use of the normal distribution**              | Even if the population is skewed or unknown, we can apply normal-based methods to sample means.         |
# | **2. Justifies confidence intervals and hypothesis tests** | Most classical statistical methods rely on normality — CLT makes these methods valid for large samples. |
# | **3. Simplifies analysis**                                 | We don’t always need to know the exact population distribution.                                         |
# | **4. Foundation of inferential statistics**                | Allows estimation of population parameters from sample data.                                            |
#
# Real-World Example
# Suppose the time it takes for a customer to be served at a fast-food restaurant is not normally distributed (it may be skewed).
#
# You take many random samples of 30 customers and calculate the mean service time for each sample.
#
# According to the CLT, the distribution of these sample means will be approximately normal, even if the original data isn’t.
#
# 📊 Practical Guidelines
# Works well for sample sizes
# 𝑛
# ≥
# 30
# n≥30
#
# If the population is very skewed or has outliers, larger samples may be needed
#
# The theorem applies not just to sample means, but also to sums of i.i.d. variables
#
# 📌 In Summary:
#
# Feature	Description
# Applies to	Sample means (or sums) of i.i.d. variables
# Requires	Finite mean and variance
# Result	Sampling distribution ≈ Normal
# Importance	Forms the foundation of statistical inference

# %% [markdown]
# # **14) How does the Central Limit Theorem relate to the normal distribution?**
#
# ans- The Central Limit Theorem (CLT) is one of the most fundamental concepts in statistics. It explains why normal distributions are so common, even when the underlying data are not normally distributed.
#
# 🎯 Definition of the Central Limit Theorem
# The Central Limit Theorem states:
#
# Given a sufficiently large sample size, the sampling distribution of the sample mean will approximate a normal distribution, regardless of the shape of the population distribution — provided the population has a finite mean and variance.
#
# 📐 Mathematical Form
# Let:
#
# 𝑋
# 1
# ,
# 𝑋
# 2
# ,
# …
# ,
# 𝑋
# 𝑛
# X
# 1
# ​
#  ,X
# 2
# ​
#  ,…,X
# n
# ​
#   be i.i.d. random variables with mean
# 𝜇
# μ and standard deviation
# 𝜎
# σ
#
# Then the sample mean
# 𝑋
# ˉ
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# 𝑋
# 𝑖
# X
# ˉ
#  =
# n
# 1
# ​
#  ∑
# i=1
# n
# ​
#  X
# i
# ​
#
#
# As
# 𝑛
# →
# ∞
# n→∞,
#
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# →
# 𝑑
# 𝑁
# (
# 0
# ,
# 1
# )
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# d
# ​
#  N(0,1)
# This means the standardized sample mean converges in distribution to a standard normal distribution.
#
# ✅ Why It’s Critical in Statistics| Reason                                                     |                                                                                                     | Reason                                                     | Explanation                                                                                             |
# | ---------------------------------------------------------- | ------------------------------------------------------------------------------------------------------- |
# | **1. Enables use of the normal distribution**              | Even if the population is skewed or unknown, we can apply normal-based methods to sample means.         |
# | **2. Justifies confidence intervals and hypothesis tests** | Most classical statistical methods rely on normality — CLT makes these methods valid for large samples. |
# | **3. Simplifies analysis**                                 | We don’t always need to know the exact population distribution.                                         |
# | **4. Foundation of inferential statistics**                | Allows estimation of population parameters from sample data.                                            |
#
# 🧪 Real-World Example
# Suppose the time it takes for a customer to be served at a fast-food restaurant is not normally distributed (it may be skewed).
#
# You take many random samples of 30 customers and calculate the mean service time for each sample.
#
# According to the CLT, the distribution of these sample means will be approximately normal, even if the original data isn’t.
#
# 📊 Practical Guidelines
# Works well for sample sizes
# 𝑛
# ≥
# 30
# n≥30
#
# If the population is very skewed or has outliers, larger samples may be needed
#
# The theorem applies not just to sample means, but also to sums of i.i.d. variables
#
# 📌 In Summary:
#
# | Feature    | Description                                   |
# | ---------- | --------------------------------------------- |
# | Applies to | Sample means (or sums) of i.i.d. variables    |
# | Requires   | Finite mean and variance                      |
# | Result     | Sampling distribution ≈ Normal                |
# | Importance | Forms the foundation of statistical inference |
#                                     |

# %% [markdown]
# # **15) What is the application of Z statistics in hypothesis testing?**
#
# ans- ChatGPT said:
# 📌 What Is the Application of Z-Statistics in Hypothesis Testing?
# Z-statistics (or Z-scores) are widely used in hypothesis testing when the data are approximately normally distributed and the population standard deviation is known (or the sample size is large enough for the Central Limit Theorem to apply).
#
# ✅ Key Applications of Z-Statistics in Hypothesis Testing
#
# | Step                                               | Purpose                                                    | How Z Is Used                                        |
# | -------------------------------------------------- | ---------------------------------------------------------- | ---------------------------------------------------- |
# | **1. Define Hypotheses**                           | Set up the null ($H_0$) and alternative ($H_1$) hypotheses | Z helps decide whether to reject $H_0$               |
# | **2. Compute Test Statistic**                      | Convert sample data into a Z-score                         | \[                                                   |
# | Z = \frac{\bar{X} - \mu\_0}{\sigma / \sqrt{n}}     |                                                            |                                                      |
# | ]                                                  |                                                            |                                                      |
# | **3. Compare With Critical Value or Find p-value** | Check if the observed Z falls in the rejection region      | Use Z-tables or normal distribution                  |
# | **4. Make a Decision**                             | Accept or reject the null hypothesis                       | Based on comparison with significance level $\alpha$ |
#
# 📐 When to Use a Z-Test
# You use Z-statistics when:
#
# The population is normally distributed or the sample size is large (n ≥ 30).
#
# The population standard deviation
# 𝜎
# σ is known.
#
# You're testing:
#
# A single population mean
#
# A difference between two means (if variances are known)
#
# Proportions (in large samples)
#
# 🔍 Example Scenario
# Problem: A machine fills soda cans. The company claims the mean volume is 355 ml. A quality control analyst samples 36 cans and finds the mean to be 352 ml with a known population standard deviation of 10 ml.
#
# Hypothesis Test:
#
# 𝐻
# 0
# :
# 𝜇
# =
# 355
# H
# 0
# ​
#  :μ=355
#
# 𝐻
# 1
# :
# 𝜇
# <
# 355
# H
# 1
# ​
#  :μ<355
#
# Significance level:
# 𝛼
# =
# 0.05
# α=0.05
#
# Z-statistic:
#
# 𝑍
# =
# 352
# −
# 355
# 10
# /
# 36
# =
# −
# 3
# 1.67
# ≈
# −
# 1.80
# Z=
# 10/
# 36
# ​
#
# 352−355
# ​
#  =
# 1.67
# −3
# ​
#  ≈−1.80
# Critical value at
# 𝛼
# =
# 0.05
# α=0.05:
# 𝑍
# =
# −
# 1.645
# Z=−1.645
#
# Since
# −
# 1.80
# <
# −
# 1.645
# −1.80<−1.645, reject
# 𝐻
# 0
# H
# 0
# ​
#   → there's evidence the machine underfills.
#
# 🔢 Types of Z-Tests
#
# | Test Type                  | Purpose                                            |
# | -------------------------- | -------------------------------------------------- |
# | **One-sample Z-test**      | Test a sample mean against a known population mean |
# | **Two-sample Z-test**      | Compare the means of two independent populations   |
# | **Z-test for proportions** | Test population proportion(s) in binary outcomes   |
#
# 🎯 Why Z-Statistics Matter
# Simple and powerful when assumptions are met
#
# Foundation for many parametric tests
#
# Frequently used in quality control, clinical trials, surveys, and A/B testing

# %% [markdown]
# # ** 16) How do you calculate a Z-score, and what does it represent?**
#
# ans- ✅ What Is a Z-Score?
# A Z-score (or standard score) tells you how many standard deviations a data point is from the mean of a distribution. It’s a way of standardizing values so you can compare them on a common scale, especially when data come from different units or distributions.
#
# 🧮 Z-Score Formula
# For a value
# 𝑋
# X in a distribution with mean
# 𝜇
# μ and standard deviation
# 𝜎
# σ:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# ​
#
# 𝑋
# X = individual data value
#
# 𝜇
# μ = population mean
#
# 𝜎
# σ = population standard deviation
#
# 📐 What a Z-Score Represents
#
# | Z-score | Interpretation                   |       |                                                 |
# | ------- | -------------------------------- | ----- | ----------------------------------------------- |
# | $Z = 0$ | The value is exactly at the mean |       |                                                 |
# | $Z > 0$ | The value is above the mean      |       |                                                 |
# | $Z < 0$ | The value is below the mean      |       |                                                 |
# | (       | Z                                | = 1 ) | 1 standard deviation away from the mean         |
# | (       | Z                                | > 2 ) | Unusual or extreme value (depending on context) |
#
# 🔍 Example Calculation
# Imagine student test scores are normally distributed with:
#
# Mean = 70
#
# Standard deviation = 10
#
# A student scores 85.
#
# 𝑍
# =
# 85
# −
# 70
# 10
# =
# 15
# 10
# =
# 1.5
# Z=
# 10
# 85−70
# ​
#  =
# 10
# 15
# ​
#  =1.5
# ✅ Interpretation: The student scored 1.5 standard deviations above the mean, which places them around the 93rd percentile.
#
# 📊 Uses of Z-Scores
#
# | Application            | Purpose                                                                                 |   |                                             |
# | ---------------------- | --------------------------------------------------------------------------------------- | - | ------------------------------------------- |
# | **Hypothesis testing** | Convert test statistic to Z-score to calculate p-values                                 |   |                                             |
# | **Comparing scores**   | Compare values across different distributions (e.g., test results from different exams) |   |                                             |
# | **Outlier detection**  | Values with (                                                                           | Z | > 2 ) or $> 3$ are often considered unusual |
# | **Standardization**    | Transform data for machine learning models or statistical analysis                      |   |                                             |

# %% [markdown]
# # **17) What are point estimates and interval estimates in statistics?**
#
# ans- In statistics, point estimates and interval estimates are two ways to infer or estimate population parameters (like the mean or proportion) using sample data. Here's a clear explanation of each:
#
# 1. Point Estimate
# A point estimate is a single value used to approximate a population parameter.
#
# Example:
# If you're estimating the average height of all college students based on a sample, the sample mean is a point estimate of the population mean.
#
# Common Point Estimates:
#
# Sample mean (𝑥̄) estimates population mean (μ)
#
# Sample proportion (p̂) estimates population proportion (p)
#
# Sample standard deviation (s) estimates population standard deviation (σ)
#
# Advantage: Simple and direct
#
# Limitation: Gives no information about the precision or reliability of the estimate
#
# 2. Interval Estimate
# An interval estimate gives a range of values, called a confidence interval, which is likely to contain the population parameter.
#
# Example:
# "We are 95% confident that the population mean height is between 165 cm and 175 cm."
#
# Form:
#
# Point Estimate
# ±
# Margin of Error
# Point Estimate±Margin of Error
# Confidence Interval (CI):
#
# 95% CI means that if you repeated the sampling many times, about 95% of the intervals would contain the true population parameter.
#
# Wider intervals mean more uncertainty; narrower intervals mean more precision.
#
# Common Confidence Levels: 90%, 95%, 99%
#
# Summary Table:
#
# | Feature            | Point Estimate                   | Interval Estimate                         |
# | ------------------ | -------------------------------- | ----------------------------------------- |
# | Definition         | Single best guess of a parameter | Range of plausible values for a parameter |
# | Precision          | High (but possibly inaccurate)   | Lower (but more informative)              |
# | Uncertainty shown? | ❌ No                             | ✅ Yes                                     |
# | Example            | Sample mean = 170 cm             | Mean is between 165–175 cm                |
#
#
# Why Both Matter
#
# Point estimates are useful for simplicity and quick summaries.
#
# Interval estimates are critical for understanding the reliability and uncertainty in your estimation, especially in decision-making and scientific studies.

# %% [markdown]
# # **18) What is the significance of confidence intervals in statistical analysis?**
#
# ans- Significance of Confidence Intervals in Statistical Analysis
# Confidence intervals (CIs) are crucial tools in statistics because they provide a range of values that likely contain the true population parameter. Their significance lies in how they help us understand uncertainty, reliability, and precision of estimates.
#
# ✅ 1. Quantify Uncertainty
# Point estimates (like sample means) alone don't show how accurate they are.
#
# Confidence intervals express the range of plausible values, acknowledging that sample data can vary due to chance.
#
# 🔹 Example: Instead of saying, "The average test score is 78", a 95% CI might say, "The average is between 75 and 81", which accounts for sampling variability.
#
# ✅ 2. Support Better Decision Making
# CIs help in making informed conclusions.
#
# For instance, if a 95% CI for the effect of a new drug on blood pressure is (−10, −2), this indicates the drug is likely effective (since the entire interval is negative).
#
# ✅ 3. Indicate Statistical Significance
# If a CI for a difference or effect does not include 0, it suggests a statistically significant result.
#
# This is often used instead of p-values in modern reporting for more interpretability.
#
# 🔹 Example:
# If a 95% CI for the mean difference is (2.1, 4.3), it suggests the difference is statistically significant (since 0 is not in the interval).
#
# ✅ 4. Communicate Precision of Estimates
# Narrower intervals imply more precise estimates (usually due to larger sample sizes or less variability).
#
# Wider intervals indicate more uncertainty and the need for more data or better sampling.
#
# ✅ 5. Used in Hypothesis Testing
# Confidence intervals are closely tied to hypothesis testing.
#
# If the null value lies outside the interval, we reject the null hypothesis at the corresponding confidence level.
#
# Summary Table:
#
# | **Purpose**                           | **Role of Confidence Intervals**                         |
# | ------------------------------------- | -------------------------------------------------------- |
# | Measure of uncertainty                | Shows range likely to contain the population parameter   |
# | Indicator of statistical significance | Helps determine if a result is likely due to chance      |
# | Communication of results              | Offers a clearer interpretation than just a single point |
# | Basis for comparison                  | Used to compare groups, treatments, or trends            |
# In Simple Terms:
# A confidence interval doesn’t say “the true value is exactly this,”
# it says “we’re pretty confident the true value is somewhere in this range.”

# %% [markdown]
# # **19)What is the relationship between a Z-score and a confidence interval?**
#
# ans- The relationship between a Z-score and a confidence interval lies in how we use the Z-score to construct and interpret confidence intervals in statistics.
#
# 🔹 What is a Z-score?
# A Z-score (or standard score) measures how many standard deviations a data point is from the mean:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# In estimation problems (like constructing a confidence interval), we often use the Z-critical value (from the standard normal distribution), which corresponds to a desired confidence level.
#
# 🔹 What is a Confidence Interval (CI)?
# A confidence interval gives a range of values that likely contains the true population parameter (like the mean) with a certain level of confidence (e.g., 95%).
#
# 🔹 How They Are Related:
# To construct a confidence interval for a population mean (when population standard deviation
# 𝜎
# σ is known), we use the Z-score from the standard normal distribution.
#
# 🔸 Formula for CI using Z-score:
# CI
# =
# 𝑥
# ˉ
# ±
# 𝑍
# 𝛼
# /
# 2
# ⋅
# 𝜎
# 𝑛
# CI=
# x
# ˉ
#  ±Z
# α/2
# ​
#  ⋅
# n
# ​
#
# σ
# ​
#
# Where:
#
# 𝑥
# ˉ
# x
# ˉ
#   = sample mean
#
# 𝑍
# 𝛼
# /
# 2
# Z
# α/2
# ​
#   = Z-score that leaves
# 𝛼
# /
# 2
# α/2 in each tail
#
# 𝜎
# σ = population standard deviation
#
# 𝑛
# n = sample size
#
# 🔹 Common Z-scores and Confidence Levels:
# Confidence Level	Z-score (
# 𝑍
# 𝛼
# /
# 2
# Z
# α/2
# ​
#  )
# 90%	1.645
# 95%	1.960
# 99%	2.576
#
# These Z-scores define the margin of error in a confidence interval.
#
# 🔹 In Summary:
#
# A Z-score quantifies how extreme a value is in standard deviations.
#
# A Z-critical value defines the boundaries of a confidence interval.
#
# Larger confidence levels → larger Z-scores → wider confidence intervals.

# %% [markdown]
# # **20) How are Z-scores used to compare different distributions?**
#
# ans- Z-scores are used to compare values from different distributions by standardizing them—transforming them onto the same scale, regardless of the original distribution’s mean or standard deviation.
#
# 🔹 Why Use Z-scores to Compare Distributions?
# Different datasets may have:
#
# Different means (μ)
#
# Different standard deviations (σ)
#
# Different units (e.g., test scores vs. weights)
#
# Z-scores remove the effects of these differences and allow direct comparison.
#
# 🔹 Z-score Formula Recap
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# Where:
#
# 𝑋
# X = original value
#
# 𝜇
# μ = mean of the distribution
#
# 𝜎
# σ = standard deviation of the distribution
#
# 🔹 How They Enable Comparison
# Once data points from different distributions are converted to Z-scores:
#
# A higher Z-score means the value is farther above its mean (in standard deviations).
#
# A lower Z-score means the value is farther below its mean.
#
# ✅ Example:
# Alice scores 85 on a test where the mean is 70 and SD is 10.
#
# Bob scores 78 on another test with a mean of 60 and SD of 12.
#
# Alice’s Z-score:
#
# 𝑍
# 𝐴
# =
# 85
# −
# 70
# 10
# =
# 1.5
# Z
# A
# ​
#  =
# 10
# 85−70
# ​
#  =1.5
# Bob’s Z-score:
#
# 𝑍
# 𝐵
# =
# 78
# −
# 60
# 12
# =
# 1.5
# Z
# B
# ​
#  =
# 12
# 78−60
# ​
#  =1.5
# 🔸 Conclusion: Even though the scores are different, both Alice and Bob scored 1.5 standard deviations above their respective means — making their performances equally strong relative to their groups.
#
# 🔹 Summary:
#
# Z-scores standardize values so they can be compared across distributions.
#
# They normalize different units, means, and variances.
#
# The higher the Z-score, the more "exceptional" or "unusual" the value is within its own distribution.

# %% [markdown]
# # **21) What are the assumptions for applying the Central Limit Theorem?**
#
# ans- The Central Limit Theorem (CLT) is a cornerstone of inferential statistics. It states that, under certain conditions, the sampling distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the population’s distribution.
#
# ✅ Assumptions for Applying the Central Limit Theorem (CLT):
# 1. Independence of Observations
# The sampled observations must be independent.
#
# This is generally true when:
#
# Sampling is random.
#
# Sampling with replacement, or sampling without replacement from a large population (typically, if the sample is ≤10% of the population).
#
# 2. Sample Size (n) Must Be Large Enough
# The larger the sample size, the better the normal approximation.
#
# General rule of thumb:
#
# n ≥ 30 is considered sufficient for the CLT to hold.
#
# If the population is highly skewed or non-normal, you may need n > 30.
#
# If the population is already normal, small samples (even n < 30) are sufficient.
#
# 3. Finite Population Variance
# The population from which the sample is drawn must have a finite variance (
# 𝜎
# 2
# <
# ∞
# σ
# 2
#  <∞).
#
# This excludes populations with extremely heavy tails (e.g., Cauchy distribution).
#
# Optional/Practical Assumptions for More Specific Scenarios:
# 4. Identically Distributed (i.i.d.) Random Variables
# If each observation comes from the same distribution, the CLT applies more cleanly.
#
# If observations are from different distributions but have the same mean and variance, a generalized CLT still holds under more complex conditions.
#
# Summary Table:
#
# | Assumption                    | Why It Matters                                 |
# | ----------------------------- | ---------------------------------------------- |
# | Independence                  | Ensures valid combination of observations      |
# | Sufficiently large sample (n) | Enables normal approximation                   |
# | Finite population variance    | Prevents distortions from infinite variability |
# | Identically distributed       | Simplifies application and improves accuracy   |
#
# 📌 In Practice:
# Even if the population is not normal, the CLT allows us to:
#
# Use the normal distribution to make confidence intervals and perform hypothesis tests on means.
#
# Justify the use of Z-tests, t-tests, and other inferential methods.

# %% [markdown]
# # **22) What is the concept of expected value in a probability distribution?**
#
# ans- The expected value (also called the mean or mathematical expectation) of a random variable in a probability distribution is the long-run average or central value you would expect after many repetitions of a random experiment.
#
# 🔹 Definition
# The expected value represents the weighted average of all possible outcomes, where each outcome is weighted by its probability.
#
# 🔸 1. For a Discrete Random Variable:
# If a random variable
# 𝑋
# X can take values
# 𝑥
# 1
# ,
# 𝑥
# 2
# ,
# .
# .
# .
# ,
# 𝑥
# 𝑛
# x
# 1
# ​
#  ,x
# 2
# ​
#  ,...,x
# n
# ​
#   with corresponding probabilities
# 𝑃
# (
# 𝑋
# =
# 𝑥
# 𝑖
# )
# =
# 𝑝
# 𝑖
# P(X=x
# i
# ​
#  )=p
# i
# ​
#  , then:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# 𝑥
# 𝑖
# ⋅
# 𝑝
# 𝑖
# E(X)=
# i=1
# ∑
# n
# ​
#  x
# i
# ​
#  ⋅p
# i
# ​
#
# 🔸 2. For a Continuous Random Variable:
# If
# 𝑋
# X is continuous with a probability density function (PDF)
# 𝑓
# (
# 𝑥
# )
# f(x), then:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∫
# −
# ∞
# ∞
# 𝑥
# ⋅
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# E(X)=∫
# −∞
# ∞
# ​
#  x⋅f(x)dx
# 🔹 Interpretation:
# The expected value tells you the average outcome if you could repeat the random process an infinite number of times.
#
# 🔸 Example (Discrete):
# You roll a fair 6-sided die:
#
# Outcomes:
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# 1,2,3,4,5,6
#
# Each has probability
# 1
# 6
# 6
# 1
# ​
#
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑖
# =
# 1
# 6
# 𝑖
# ⋅
# 1
# 6
# =
# 1
# +
# 2
# +
# 3
# +
# 4
# +
# 5
# +
# 6
# 6
# =
# 3.5
# E(X)=
# i=1
# ∑
# 6
# ​
#  i⋅
# 6
# 1
# ​
#  =
# 6
# 1+2+3+4+5+6
# ​
#  =3.5
# So, 3.5 is the expected value—even though it's not an actual roll result, it's the average over time.
#
# 🔸 Example (Continuous):
# For a uniform distribution on [0, 1]:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# for
# 0
# ≤
# 𝑥
# ≤
# 1
# f(x)=1for 0≤x≤1
# 𝐸
# (
# 𝑋
# )
# =
# ∫
# 0
# 1
# 𝑥
# ⋅
# 1
#
# 𝑑
# 𝑥
# =
# [
# 𝑥
# 2
# 2
# ]
# 0
# 1
# =
# 1
# 2
# E(X)=∫
# 0
# 1
# ​
#  x⋅1dx=[
# 2
# x
# 2
#
# ​
#  ]
# 0
# 1
# ​
#  =
# 2
# 1
# ​
#
# Summary:
#
# | Concept            | Description                               |
# | ------------------ | ----------------------------------------- |
# | Expected Value     | Long-run average of a random variable     |
# | Discrete Formula   | $\sum x_i \cdot P(x_i)$                   |
# | Continuous Formula | $\int x \cdot f(x) \, dx$                 |
# | Purpose            | Predicts average outcome over many trials |

# %% [markdown]
# # **23) How does a probability distribution relate to the expected outcome of a random variable?**
#
# ans- A probability distribution defines how the probabilities are assigned to the possible values of a random variable, and it is the key to understanding its expected outcome.
#
# 🔹 Relationship Between Probability Distribution and Expected Outcome
# A random variable has a range of possible outcomes. The probability distribution tells you how likely each outcome is.
#
# The expected outcome (expected value or mean) is a summary statistic derived from this distribution — a weighted average of all possible outcomes, where the weights are the probabilities from the distribution.
#
# 🔸 Discrete Case:
# If a discrete random variable
# 𝑋
# X has a probability distribution:
#
# Outcomes:
# 𝑥
# 1
# ,
# 𝑥
# 2
# ,
# .
# .
# .
# ,
# 𝑥
# 𝑛
# x
# 1
# ​
#  ,x
# 2
# ​
#  ,...,x
# n
# ​
#
#
# Corresponding probabilities:
# 𝑃
# (
# 𝑋
# =
# 𝑥
# 𝑖
# )
# =
# 𝑝
# 𝑖
# P(X=x
# i
# ​
#  )=p
# i
# ​
#
#
# Then the expected value is:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# 𝑥
# 𝑖
# ⋅
# 𝑝
# 𝑖
# E(X)=
# i=1
# ∑
# n
# ​
#  x
# i
# ​
#  ⋅p
# i
# ​
#
# 🟢 The distribution gives the
# 𝑥
# 𝑖
# x
# i
# ​
#   and
# 𝑝
# 𝑖
# p
# i
# ​
#   — the expected value is calculated from them.
#
# 🔸 Continuous Case:
# For a continuous random variable
# 𝑋
# X with probability density function (PDF)
# 𝑓
# (
# 𝑥
# )
# f(x), the expected value is:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∫
# −
# ∞
# ∞
# 𝑥
# ⋅
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# E(X)=∫
# −∞
# ∞
# ​
#  x⋅f(x)dx
# 🟢 Here, the PDF
# 𝑓
# (
# 𝑥
# )
# f(x) is the probability distribution, and it's used to compute the expected outcome.
#
# 🔹 Key Insight:
# ✅ The probability distribution determines how likely each outcome is — the expected value summarizes the average of those outcomes over the long run.
#
# 🔸 Example (Discrete):
# A biased coin has the following distribution:
#
# 𝑃
# (
# Heads
# )
# =
# 0.7
# P(Heads)=0.7,
# 𝑃
# (
# Tails
# )
# =
# 0.3
# P(Tails)=0.3
#
# Let
# 𝑋
# =
# 1
# X=1 if heads,
# 𝑋
# =
# 0
# X=0 if tails
#
# 𝐸
# (
# 𝑋
# )
# =
# 1
# ⋅
# 0.7
# +
# 0
# ⋅
# 0.3
# =
# 0.7
# E(X)=1⋅0.7+0⋅0.3=0.7
# 👉 So, on average, you'd expect 0.7 heads per flip — derived directly from the distribution.
#
# Summary:
#
# | Concept                  | Role                                               |
# | ------------------------ | -------------------------------------------------- |
# | Probability Distribution | Describes the likelihood of each outcome           |
# | Expected Value           | Weighted average using the distribution            |
# | Relationship             | Expected value is computed *from* the distribution |
